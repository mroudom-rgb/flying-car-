# %% [markdown]
# <a href="https://colab.research.google.com/github/mroudom-rgb/flying-car-/blob/main/Maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import list, tuple
#create a new map
my_map = {}

#1. basic operation
print("=== BASIC OPERATION ===")

#Adding key-value pairs
my_map["name"] = "Oudom"
my_map["age"] = 30
my_map["city"] = "New York"
my_map["occupation"] = "Software Engineer"

print(f"initail map: {my_map}")
print(f"size: {len(my_map)}")

#accesing value
print(f"name: {my_map['name']}")
print(f"age: {my_map['age']}")

#updating value
my_map["age"] = 31
print(f"updated age: {my_map['age']}")

#checking existence
print(f"has 'city': {'city' in my_map}")
print(f"has 'country': {'country' in my_map}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-934022968.py in <cell line: 0>()
# ----> 1 from typing import list, tuple
#       2 #create a new map
#       3 my_map = {}
#       4
#       5 #1. basic operation
#
# ImportError: cannot import name 'list' from 'typing' (/usr/lib/python3.12/typing.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
